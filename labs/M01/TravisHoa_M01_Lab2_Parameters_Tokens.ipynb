# %% [markdown]
# <a href="https://colab.research.google.com/github/thoa1/website/blob/main/labs/M01/TravisHoa_M01_Lab2_Parameters_Tokens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- dads-lab-header -->
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mdehghani86/DADS5250-GenAI/blob/main/labs/M01/M01_Lab2_Parameters_Tokens.ipynb)
#
# ![M01 Lab2 Parameters Tokens](https://raw.githubusercontent.com/mdehghani86/DADS5250-GenAI/main/labs/M01/assets/images/M01_Lab2_Parameters_Tokens_banner.png)

# %%
# === Shared lab setup: install dads5250 + load API key + sticky pill ===
# Installs the shared utilities (pp, pretty_print, lab_pill, model constants,
# setup_openai, setup_gemini) once per Colab runtime. The same OPENAI_API_KEY
# / GEMINI_API_KEY Colab secrets are used across every DADS 5250 lab, set
# them once in the 🔑 sidebar and they're picked up automatically.
import os
# Course toolkit: the shared dads5250 helpers, installed from PyPI (pypi.org/project/dads5250).
# Pinned to ==0.2.0 so this notebook runs exactly as recorded. Bump the version here to upgrade.
import importlib.util
if importlib.util.find_spec("dads5250") is None:
    # !pip install -q dads5250==0.3.0

from dads5250 import (
    pp,
    pretty_print,
    lab_pill,
    setup_openai,
    setup_gemini,
    DEFAULT_CHAT_MODEL,  # newest reasoning model that supports temperature
    DEFAULT_MINI_MODEL,  # newest mini model that supports temperature
    DEFAULT_EMBED_MODEL, # current embeddings default
    DEFAULT_GEMINI_MODEL, # tracks the latest stable flash
)

lab_pill('M01 Lab 2, Parameters & Tokens')            # sticky banner so you always see which lab you're in
# Out:
#     <div style="position: sticky; top: 0; z-index: 9999; text-align: center;
#                 padding: 6px 0; pointer-events: none;">
#       <span style="display: inline-block; background: #0055d4; color: white;
#                    padding: 6px 16px; border-radius: 999px;
#                    font-family: 'Segoe UI', sans-serif; font-size: 12px;
#                    font-weight: 600; letter-spacing: 0.5px;
#                    box-shadow: 0 2px 6px rgba(0,0,0,0.15);">
#         📘 M01 Lab 2, Parameters & Tokens
#       </span>
#     </div>

# %% [markdown]
# ## API check
#
# Confirm the API connection before we start. Your key is read from a Colab Secret, an environment variable, or a hidden prompt if neither is set.
#
# **Running in Jupyter or JupyterHub instead of Colab?** There are no Colab Secrets there, so do either:
# - Just run the setup cell and paste your key when it prompts (the input is hidden and not saved), or
# - Set it first: in a terminal run `export OPENAI_API_KEY=sk-...`, or in a cell run `import os; os.environ["OPENAI_API_KEY"] = "sk-..."`.

# %%
# === API check: confirm the connection and show the model(s) this lab uses ===
client = setup_openai()        # loads OPENAI_API_KEY + verifies it works

pp({
    "OpenAI":      "connected",
    "chat model":  DEFAULT_CHAT_MODEL,
    "mini model":  DEFAULT_MINI_MODEL,
    "embed model":  DEFAULT_EMBED_MODEL,
}, title="API check")
# Out:
# OpenAI ready  |  model: gpt-5.4-mini  |  status: connected
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">API check</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "OpenAI": "connected",
#   "chat model": "gpt-5.4",
#   "mini model": "gpt-5.4-mini",
#   "embed model": "text-embedding-3-small"
# }</pre>
#     </div>

# %% [markdown]
# <a href="https://colab.research.google.com/github/mdehghani86/AppliedGenAI/blob/main/ChatGPT_API_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎛️ Parameters & Tokens: Steering the Model
#
# **Why this matters.** In Lab 1 you learned how to *reach* a language model. This lab is about *controlling* it. The exact same prompt can produce a one-line answer or a rambling essay, a bone-dry factual reply or a wildly creative one, depending on a handful of settings you pass with each request. If you do not understand those settings, the model feels unpredictable and expensive. Once you do, you can dial it in for the job at hand.
#
# **What you will control.** Two ideas do most of the work. **Roles** (system, user, assistant) shape *who the model thinks it is* and what the conversation looks like, which sets the tone and reliability of every answer. **Parameters** like `max_tokens` and `temperature` shape *how* the model responds: how long it may talk and how adventurous it is allowed to be. Along the way you will also meet **tokens**, the unit the model actually reads, writes, and bills in, so you can reason about cost and length instead of guessing.
#
# **By the end of this lab you will be able to:**
#
# - 🟢 **Use roles** (system / user / assistant) to set the assistant's behavior and prime a conversation.
# - 🌟 **Tune `max_tokens` and `temperature`** and *feel* the difference in real responses.
# - ✨ **Generate images** from a text prompt with the OpenAI SDK.
# - 🔧 **Create vector embeddings** and measure how close two pieces of text are in meaning.
#
# Let's start by looking at the roles that frame every single API call.

# %%
# Install the OpenAI Python SDK
# This library allows us to interact with OpenAI's API for text, images, and embeddings.
# !pip install openai

# %%
# ==========================================================
# 0. Quick connection test
# ==========================================================
# A tiny round-trip to the API before we do anything else. If this cell
# reports "connected", the SDK, your key, and the model name are all wired
# up correctly and every later cell will work.
# `client` comes from the setup cell above; re-creating it here would lose
# the provider routing that setup_openai() wired for alternative providers.

import openai                     # the SDK; imported so its version is available

# Send the smallest possible request: one short user message, no tuning.
try:
    response = client.chat.completions.create(
        model=DEFAULT_CHAT_MODEL,                                  # the model this lab uses
        messages=[{"role": "user", "content": "Connection test"}], # a throwaway prompt
    )
    status = "connected"          # we got a response object back, so the call worked
    detail = response.choices[0].message.content                    # the model's reply text
except Exception as e:            # anything failed: bad key, no network, wrong model name
    status = "failed"
    detail = str(e)               # keep the error text so we can read what went wrong

# Show the outcome with pp so success and failure look the same and read cleanly.
pp({"OpenAI": status, "model": DEFAULT_CHAT_MODEL, "detail": detail},
   title="Quick connection test")
# Out:
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">Quick connection test</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "OpenAI": "connected",
#   "model": "gpt-5.4",
#   "detail": "Connected and ready."
# }</pre>
#     </div>

# %% [markdown]
# ## 1. 🎯 Prompt Playground: Understanding Roles
#
# Every message you send to a chat model carries a **role**, and the role tells the model *how to read* that message. This is not decoration: it is the main lever you have for shaping behavior before you touch any parameter.
#
# - ➡️ **System**, sets the assistant's persona, rules, and tone for the whole conversation (e.g. *"You are a strict math tutor who shows every step."*). Think of it as standing instructions the model should always keep in mind.
# - ➡️ **User**, the actual question or request coming from the person (e.g. *"Solve for x: 2x + 5 = 15"*).
# - ➡️ **Assistant**, the model's own replies. You can also *supply* assistant turns yourself to show the model an example of how it should have answered, which primes it to continue in that style.
#
# 💡 **Why roles matter.** The same user question produces very different answers depending on the system message. *"You are a strict teacher"* yields a formal, rigorous reply; *"You are a friendly chatbot"* yields something casual. Getting the system role right is often more effective than any amount of parameter tuning, because it frames everything the model does next.
#
# We will run the same math question twice: first with only system + user, then again after we hand the model a sample assistant turn, so you can see how priming changes the flow.
#
# ### Example 1: Without an Assistant Role

# %%
# ==========================================================
# 1. Roles in action -- system + user only
# ==========================================================

# Demonstrating roles in OpenAI's API without the assistant role

# Define the conversation using only system and user roles
messages = [
    {"role": "system", "content": "You are a math tutor who explains problems step by step."}, # System role sets the behavior
    {"role": "user", "content": "Solve for x: 2x + 5 = 15"}  # User question
]

# Send the conversation to the API
response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL, # Use the chosen model
    messages=messages  # Pass the conversation
)

# Print the assistant's response
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">Solve:<br><br>\[<br>2x + 5 = 15<br>\]<br><br>Step 1: Subtract 5 from both sides.<br><br>\[<br>2x = 10<br>\]<br><br>Step 2: Divide both sides by 2.<br><br>\[<br>x = 5<br>\]<br><br>Final answer: \(\boxed{5}\)</span>
#     </div>

# %% [markdown]
# ### Example 2: With an Assistant Role
#
# Now we add a third message with the **assistant** role *before* sending the request. This is a technique called **priming**: by including an example of how the assistant already answered, we show the model the exact style, format, and level of detail we want it to continue with. The model treats that supplied turn as part of the conversation history and mirrors it in what it generates next. This is the simplest form of "few-shot" prompting, and you will use it constantly to lock in a consistent voice or output shape.

# %%
# ==========================================================
# 1. Roles in action -- add an assistant turn
# ==========================================================

# Demonstrating roles in OpenAI's API with the assistant role

# Define the conversation including a predefined assistant response
messages = [
    {"role": "system", "content": "You are a math tutor who explains problems step by step."}, # System role sets the behavior
    {"role": "user", "content": "Solve for x: 2x + 5 = 15"}, # User question
    {"role": "assistant", "content": "To solve for x: \n1. Subtract 5 from both sides: 2x = 10\n2. Divide both sides by 2: x = 5"}  # Predefined assistant response
]

# Send the conversation to the API
response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL, # Use the chosen model
    messages=messages  # Pass the conversation
)

# Print the assistant's response
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">Solve \(2x + 5 = 15\):<br><br>1. Subtract 5 from both sides:<br>   \[<br>   2x = 10<br>   \]<br><br>2. Divide both sides by 2:<br>   \[<br>   x = 5<br>   \]<br><br>**Answer: \(x = 5\)**</span>
#     </div>

# %% [markdown]
# ## 🧮 Hands-On: Build a Three-Role Conversation
#
# Your turn to wire up all three roles yourself. In the next cell, replace each `----` placeholder with the correct role name (`system`, `user`, or `assistant`) so the conversation makes sense: standing instructions first, the question second, and a primed example answer third. Then uncomment the API call and run it to see the model continue in the style you set up.

# %%
# ==========================================================
# 1. Hands-on: complete the roles
# ==========================================================

# ++++ Hands-On: Complete the Roles ++++

# Define the conversation using the role structure
messages = [
    {"role": "system", "content": "You are a math tutor who explains concepts clearly and step by step."},
    {"role": "user", "content": "How do you calculate the arithmetic mean of a set of numbers?"},
    {"role": "assistant", "content": "To calculate the arithmetic mean:\n"
                                      "1. Add all the numbers in the set.\n"
                                      "2. Divide the sum by the number of numbers.\n\n"
                                      "For example, for 10, 20, and 30:\n"
                                      "Mean = (10 + 20 + 30) / 3 = 60 / 3 = 20."}
]

# Uncomment the code below after completing the placeholders
response = client.chat.completions.create(
     model=DEFAULT_CHAT_MODEL, # Specify the model
     messages=messages  # Pass the completed conversation
 )
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
# ...

# %% [markdown]
# ## 2. 🎯 Function Playground: Simplify OpenAI API Calls
#
# Look back at the last few cells: each one repeats the same boilerplate to call the API, unpack `response.choices[0].message.content`, and handle errors. Copying that block everywhere is tedious and easy to get wrong. The fix is to wrap it once in a small **helper function** and call that instead.
#
# - ➡️ **Input**: a list of `messages` (the roles and content), plus optional tuning knobs.
# - ➡️ **Output**: just the assistant's reply as a plain string.
#
# 💡 **Why use a helper.** Wrapping the call keeps every later cell short and readable, puts error handling in one place, and gives us one obvious spot to expose the two parameters this lab is really about: `max_tokens` and `temperature`. Change the helper once and every call improves.

# %% [markdown]
# **Two knobs you will use everywhere: `max_tokens` and `temperature`.**
#
# - **Tokens** are the pieces of text the model reads and writes. A token is roughly 4 characters, or about 3/4 of a word, so "understanding" is a few tokens, not one. You pay per token, and every model has a token limit, so tokens are the currency of LLM work.
# - **`max_tokens`** caps how long the *response* can be. A small value keeps answers short and cheap; too small and the reply gets cut off mid-sentence.
# - **`temperature`** controls randomness, on a scale from 0 to about 2. Near **0** the model is focused and repeatable (good for facts and code); higher values (0.7 and up) make it more varied and creative (good for brainstorming).
#
# The `Call_ChatGPT` helper below exposes both so you can feel their effect in the two hands-on tasks that follow.

# %%
# ==========================================================
# 2. Define Call_ChatGPT (a reusable helper)
# ----------------------------------------------------------
# Defines:
#   - Call_ChatGPT() : Send messages to the OpenAI API and get the assistant's response.
# ==========================================================

def Call_ChatGPT(messages, model=DEFAULT_CHAT_MODEL, max_tokens=100, temperature=0.7):
    """
    Send messages to the OpenAI API and get the assistant's response.

    Parameters:
    - messages (list): A list of message dictionaries with 'role' and 'content'.
    - model (str): The model to use (default is DEFAULT_CHAT_MODEL).
    - max_tokens (int): The maximum number of tokens to include in the response.
    - temperature (float): The sampling temperature (0.0 to 1.0, higher means more creative).

    Returns:
    - str: The assistant's response content.
    """
    try:
        # One API call, but now the two tuning knobs are exposed as arguments
        response = client.chat.completions.create(
            model=model,                # which model answers
            messages=messages,          # the conversation (roles + content)
            max_completion_tokens=max_tokens,      # hard cap on how long the reply may be
            temperature=temperature,    # how random / creative the reply may be
        )
        # Reach into the response object and pull out just the reply text
        return response.choices[0].message.content
    except Exception as e:
        # Never crash the notebook: return the error as a string so the caller sees it
        return f"Error: {str(e)}"

# %%
# ==========================================================
# 2. Call the helper
# ==========================================================
# Example usage: a system message that asks for concise answers, plus a question.
messages = [
    {"role": "system", "content": "You are a helpful assistant who provides concise answers."},
    {"role": "user", "content": "What is the square root of 144?"},
]

# Call our helper with custom knobs: short cap and a low, focused temperature.
response = Call_ChatGPT(messages, model=DEFAULT_CHAT_MODEL, max_tokens=50, temperature=0.5)

# Display the reply with pretty_print so model output always renders consistently
pretty_print(response, title="Assistant's Response")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response</strong><br>
#         <span style="font-size: 14px; color: #333;">The principal square root of 144 is **12**.</span>
#     </div>

# %% [markdown]
# ## 🧮 Hands-On: Using `Call_ChatGPT`
#
# ### Task 1: Call the Function Without Adjusting Options
#
# First get comfortable calling the helper with its defaults, so you can see the baseline behavior before you start tuning anything. In the next cell:
#
# 1. Fill in the **system role** to set a persona (e.g. *"You are a history expert who gives brief answers."*).
# 2. Fill in the **user question** you want answered.
# 3. Call `Call_ChatGPT(messages)` with **no** extra options, so it uses the default `max_tokens=100` and `temperature=0.7`.
# 4. Run the cell and note the length and tone of the reply. This is your reference point for Task 2.

# %%
# ==========================================================
# 2. Hands-on: call with default options
# ==========================================================
# ++++ Hands-On: Call ChatGPT Without Adjusting Options ++++

# Define the conversation: replace each ---- with the correct role name.
messages = [
    {"role": "system", "content": "You are a history expert who gives brief and clear answers."},
    {"role": "user", "content": "Who was the first President of the United States?"}
]


# Call the helper with NO extra options, so the defaults apply.
response = Call_ChatGPT(messages)

# Show the reply with pretty_print (never a bare print of a result)
pretty_print(response, title="Assistant's Response")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response</strong><br>
#         <span style="font-size: 14px; color: #333;">George Washington was the first President of the United States, serving from 1789 to 1797.</span>
#     </div>

# %% [markdown]
# ## 🧮 Hands-On: Using `Call_ChatGPT`
#
# ### Task 2: Call the Function With Custom Options
#
# Now change the knobs and watch the reply change. Compared with your Task 1 baseline, a smaller `max_tokens` should visibly shorten the answer (and may cut it off), while a lower `temperature` should make it more focused and repeatable. In the next cell:
#
# 1. Keep or rewrite the system + user messages.
# 2. Set the optional parameters yourself:
#    - `model` (e.g. `DEFAULT_CHAT_MODEL`),
#    - `max_tokens` (try a small value like `50`),
#    - `temperature` (try `0.2` for focused, or `0.9` for creative).
# 3. Run it and compare against Task 1. Which knob changed the *length*? Which changed the *style*?

# %%
# ==========================================================
# 2. Hands-on: call with custom options
# ==========================================================
# ++++ Hands-On: Call ChatGPT With Custom Options ++++

# A math question is a good test: low temperature should keep the steps clean.
messages = [
    {"role": "system", "content": "You are a math expert who provides step-by-step solutions to complex problems."},
    {"role": "user", "content": "Solve the equation 3x^2 - 12x + 9 = 0 and explain each step."},
]

# Fill in each ---- with a real value, then run and compare against Task 1.
response = Call_ChatGPT(
    messages,
    model=DEFAULT_CHAT_MODEL,
    max_tokens=50,
    temperature=0.2
)

# Show the reply with pretty_print for a consistent, readable result
pretty_print(response, title="Assistant's Response")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response</strong><br>
#         <span style="font-size: 14px; color: #333;">We want to solve:<br><br>\[<br>3x^2 - 12x + 9 = 0<br>\]<br><br>## Step 1: Simplify the equation<br>All terms have a common factor of 3, so divide the</span>
#     </div>

# %% [markdown]
# ## 3. 🌄 OpenAI SDK: Generate an Image
#
# Language models are not the only thing the OpenAI SDK can reach. The same client can call an **image model** that turns a text description into a picture. This is a different family of model (a *diffusion* style image generator), but from your code it looks almost identical: you send a prompt, you get back a result.
#
# **How it works in plain English.** You write a detailed description (the *prompt*) of what you want to see. The image model starts from random visual noise and, guided by your words, repeatedly refines that noise until it resembles the described scene. The more specific your prompt (subject, style, lighting, composition), the closer the result matches your intent, because the model has more to steer by.
#
# ### Key Steps:
# 1. **Craft a Prompt**, describe the image vividly, e.g. *"A futuristic city with glowing skyscrapers, flying cars, and a vibrant sunset."*
# 2. **Generate the Image**, hand the prompt to the SDK, which returns a URL (or base64 data) for the finished picture.
# 3. **Evaluate**, compare the result to what you imagined, then refine the wording and try again.
#
# <font color="#BFBB9B">Let's turn ideas into visuals! 🖼️</font>

# %%
# ==========================================================
# 3. Define an image helper
# ==========================================================

import base64
import requests
from io import BytesIO
from PIL import Image
from IPython.display import display


def generate_and_display_images(prompt, n=1, size="1024x1024"):
    """
    Generate and display images using OpenAI or the alternative provider.
    """

    import dads5250

    alt_model = getattr(dads5250, "DEFAULT_IMAGE_MODEL", None)

    try:
        # Alternative provider (CogView)
        if alt_model:
            response = client.images.generate(
                model=alt_model,
                prompt=prompt,
                n=n,
                size="1024x1024"
            )

            for item in response.data:
                res = requests.get(item.url, stream=True)

                if res.status_code == 200:
                    img = Image.open(res.raw)
                    display(img)
                else:
                    print("Failed to load image:", item.url)

        # OpenAI GPT Image
        else:
            response = client.images.generate(
                model="gpt-image-2",
                prompt=prompt,
                n=n,
                size=size
            )

            for item in response.data:
                image_bytes = base64.b64decode(item.b64_json)
                img = Image.open(BytesIO(image_bytes))
                display(img)

    except Exception as e:
        print(f"Error: {str(e)}")

# %%
# ==========================================================
# 3. Generate an image
# ==========================================================
# Example 1: a single 512x512 image from a descriptive natural-language prompt.
generate_and_display_images("A serene forest with a waterfall and sunlight streaming through the trees.")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
# ==========================================================
# 3. Generate an image (Venn diagram)
# ==========================================================
# Example 2: image models can also attempt diagrams. Note how well (or not)
# it handles text and precise structure compared with a photographic scene.
generate_and_display_images(
    "Show a clean educational Venn diagram explaining prime numbers and odd numbers.",
    n=1,
    size="1024x1024"
)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %% [markdown]
# ## 🧠 Hands-On: Generate and Display Scientific Images
#
# Now try the image model on a *scientific* subject and judge how faithful it is. Diagrams and labeled anatomy are much harder for image models than open scenes, so this is a good test of how prompt wording affects the result. In the next cell:
#
# 1. Write a **prompt** describing a scientific image (e.g. *"The anatomy of the human eye showing the cornea, lens, and retina, labeled."*).
# 2. Choose the **number of images** (`n`) and the **size** (e.g. `"512x512"`).
# 3. Pick a **response_format** (`"url"` to display it inline).
# 4. Run the cell, then look critically: did it get the structure and labels right? Rewrite the prompt and rerun to improve it.
#
# Fill in each `----` placeholder and run the code below.

# %%
# ==========================================================
# 3. Hands-on: generate a scientific image
# ==========================================================
# Fill in each ---- below with your own values, then run the cell.
prompt = "A labeled scientific diagram of the human eye showing the cornea, iris, lens, retina, and optic nerve."
n = 1
size = "1024x1024"

generate_and_display_images(prompt, n=n, size=size)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %% [markdown]
# ## 4. 🎯 OpenAI SDK: Create Vector Embeddings
#
# **Why this matters.** Computers cannot compare *meaning* directly; they compare numbers. An **embedding** solves this by turning a piece of text into a long list of numbers (a *vector*) that captures its meaning. Sentences about the same idea end up with similar vectors, even when they share no words. This is the engine behind semantic search, recommendations, clustering, and the retrieval step in the RAG systems you will build later in the course.
#
# **How it works in plain English.** An embedding model reads your text and places it as a single point in a high dimensional space (OpenAI's default model uses over a thousand dimensions). The *position* of that point encodes meaning: "a dog chased the ball" and "the puppy ran after the toy" land close together, while "quarterly tax filing" lands far away. You never interpret the individual numbers yourself. Instead you compare *distances* between points to ask "how related are these two texts?"
#
# - ➡️ **Text**, the input string you want to represent numerically.
# - ➡️ **Model**, the embedding model, e.g. the course default `DEFAULT_EMBED_MODEL`.
# - ➡️ **Embedding**, the output vector: a fixed-length list of floats that stands in for the text's meaning.
#
# 💡 **Why embeddings matter.** Once text is numeric, "which of these 10,000 documents is most relevant to this question?" becomes a fast math operation instead of an impossible reading task. We start by generating a single embedding, then compare two of them.
#
# ### Example 1: Create a Vector Embedding for Text

# %%
# ==========================================================
# 4. Embed one sentence
# ==========================================================
# We reuse the `client` from the setup cell: on an alternative provider,
# setup_openai() routes embeddings for us; a fresh OpenAI() would not.

# The sentence we want to represent as a vector.
text = "The water cycle involves processes like evaporation, condensation, and precipitation."

# Ask the embedding model to turn the text into a numeric vector.
embedding = client.embeddings.create(input=text, model=DEFAULT_EMBED_MODEL)

# The full vector is very long, so we show its size and a short preview instead
# of dumping every number. This is the numeric "fingerprint" of the meaning.
vector = embedding.data[0].embedding                 # the list of floats
pp({
    "text": text,
    "vector length": len(vector),                   # how many dimensions this model uses
    "first 8 values": [round(v, 4) for v in vector[:8]],  # a readable preview
}, title="One sentence, as an embedding")
# Out:
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">One sentence, as an embedding</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "text": "The water cycle involves processes like evaporation, condensation, and precipitation.",
#   "vector length": 1536,
#   "first 8 values": [
#     0.0005,
#     0.0459,
#     0.0606,
#     0.0098,
#     -0.0185,
#     0.0535,
#     0.0557,
#     0.0166
#   ]
# }</pre>
#     </div>

# %%
# ==========================================================
# 4. Embed several sentences
# ==========================================================
# We reuse the `client` from the setup cell: on an alternative provider,
# setup_openai() routes embeddings for us; a fresh OpenAI() would not.

# You can embed many sentences in ONE call by passing a list.
texts = [
    "Photosynthesis is the process by which plants convert light energy into chemical energy.",
    "The theory of evolution by natural selection was proposed by Charles Darwin.",
]

# One API call returns one vector per input, in the same order.
embeddings = client.embeddings.create(input=texts, model=DEFAULT_EMBED_MODEL)

# Build a small readable summary: each sentence with a preview of its vector.
summary = {}
for i, emb in enumerate(embeddings.data):            # emb.embedding is that sentence's vector
    summary[f"sentence {i + 1}"] = {
        "text": texts[i],
        "first 5 values": [round(v, 4) for v in emb.embedding[:5]],  # short preview
    }

pp(summary, title="Several sentences, each as its own vector")
# Out:
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">Several sentences, each as its own vector</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "sentence 1": {
#     "text": "Photosynthesis is the process by which plants convert light energy into chemical energy.",
#     "first 5 values": [
#       -0.0011,
#       0.0141,
#       -0.0042,
#       0.0068,
#       0.014
#     ]
#   },
#   "sentence 2": {
#     "text": "The theory of evolution by natural selection was proposed by Charles Darwin.",
#     "first 5 values": [
#       0.0764,
#       0.0183,
#       0.0319,
#       0.0246,
#       -0.0194
#     ]
#   }
# }</pre>
#     </div>

# %% [markdown]
# **What cosine similarity means.** Once two sentences are turned into embedding vectors, we need a way to say how *alike* they are. Cosine similarity measures the angle between the two vectors, ignoring their length. It runs from **-1 to 1**: near **1** means the sentences point the same way (very similar meaning), near **0** means unrelated, and negative means opposite. It is the standard "how close is this meaning" score behind semantic search.

# %%
# ==========================================================
# 4. Compare two sentences with cosine similarity
# ==========================================================
# We reuse the `client` from the setup cell: on an alternative provider,
# setup_openai() routes embeddings for us; a fresh OpenAI() would not.

import numpy as np

# Two sentences that mean the same thing but use different words.
text1 = "The Earth orbits around the Sun in an elliptical orbit."
text2 = "The Sun is the central star around which Earth revolves in an elliptical path."

# Turn each sentence into its embedding vector.
embedding1 = client.embeddings.create(input=text1, model=DEFAULT_EMBED_MODEL)
embedding2 = client.embeddings.create(input=text2, model=DEFAULT_EMBED_MODEL)

# Pull the raw float lists out of the API response objects.
vector1 = embedding1.data[0].embedding
vector2 = embedding2.data[0].embedding

# Cosine similarity = (v1 . v2) / (|v1| * |v2|): the cosine of the angle between
# the two vectors. It ignores length and measures pure direction (meaning).
# np.dot        -> the dot product of the two vectors
# np.linalg.norm-> the length (magnitude) of each vector
cosine_similarity = np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))

# Show the score with pp. Closer to 1.0 means more similar in meaning.
pp({
    "text 1": text1,
    "text 2": text2,
    "cosine similarity": round(float(cosine_similarity), 4),  # -1..1, higher = closer
}, title="How similar are these two sentences?")
# Out:
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">How similar are these two sentences?</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "text 1": "The Earth orbits around the Sun in an elliptical orbit.",
#   "text 2": "The Sun is the central star around which Earth revolves in an elliptical path.",
#   "cosine similarity": 0.7473
# }</pre>
#     </div>

# %% [markdown]
# > **Pause and think.** The two sentences above say the same thing in different words, yet their cosine similarity is well below 1.0. Why would identical meaning not score exactly 1.0? What would you expect the score to be for two *unrelated* sentences?

# %% [markdown]
# **Your notes** *(double-click to edit)*
#
# - Similarity score I saw:
# - Why it is not exactly 1.0:
# - What I would expect for two unrelated sentences:

# %% [markdown]
# ## 🧠 Hands-On: Working with Vector Embeddings
#
# Time to generate and compare embeddings yourself. You will first turn a single sentence into a vector, then measure how close two sentences are in meaning.
#
# ### Task 1: Generate a Vector Embedding for a Sentence
# 1. Write a scientific sentence (e.g. *"The law of gravity states that every object attracts every other object."*).
# 2. Generate its embedding with the embedding model.
# 3. Look at the vector's size and a preview of its values.
#
# ### Task 2: Measure Similarity Between Two Sentences
# 1. Write two sentences: try making them *related but differently worded*.
# 2. Embed both.
# 3. Compute the cosine similarity and interpret it: is the score high (similar) or low (unrelated)? Then swap in an unrelated sentence and watch the score drop.
#
# Fill in each `----` placeholder below and run the cells to complete both tasks.

# %%
# ==========================================================
# 4. Hands-on: embed your own sentence
# ==========================================================
# We reuse the `client` from the setup cell: on an alternative provider,
# setup_openai() routes embeddings for us; a fresh OpenAI() would not.

# Task 1: Generate a vector embedding for a single scientific sentence.

# Replace the ---- with your own sentence.
text = "Photosynthesis allows plants to convert sunlight into chemical energy."
# Create the embedding using the embedding model.
embedding = client.embeddings.create(input=text, model=DEFAULT_EMBED_MODEL)

# Preview the vector with pp: its length plus its first few values.
vector = embedding.data[0].embedding
pp({
    "text": text,
    "vector length": len(vector),
    "first 8 values": [round(v, 4) for v in vector[:8]],
}, title="Your sentence, as an embedding")
# Out:
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">Your sentence, as an embedding</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "text": "Photosynthesis allows plants to convert sunlight into chemical energy.",
#   "vector length": 1536,
#   "first 8 values": [
#     0.0362,
#     0.0144,
#     -0.0158,
#     0.0195,
#     0.0343,
#     0.0264,
#     0.0137,
#     0.0143
#   ]
# }</pre>
#     </div>

# %%
# ==========================================================
# 4. Hands-on: measure similarity
# ==========================================================
# We reuse the `client` from the setup cell: on an alternative provider,
# setup_openai() routes embeddings for us; a fresh OpenAI() would not.

import numpy as np

# Task 2: Measure similarity between two scientific sentences.

# Replace each ---- with your own sentence.
text1 = "Plants use sunlight to produce energy through photosynthesis."
text2 = "Photosynthesis converts light energy into chemical energy in plants."

# Turn each sentence into its embedding vector.
embedding1 = client.embeddings.create(input=text1, model=DEFAULT_EMBED_MODEL)
embedding2 = client.embeddings.create(input=text2, model=DEFAULT_EMBED_MODEL)

# Extract the raw float lists for comparison.
vector1 = embedding1.data[0].embedding
vector2 = embedding2.data[0].embedding

# Cosine similarity: dot product divided by the product of the two vector lengths.
cosine_similarity = np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))

# Show the score with pp (higher = closer in meaning).
pp({
    "text 1": text1,
    "text 2": text2,
    "cosine similarity": round(float(cosine_similarity), 4),
}, title="Similarity between your two sentences")
# Out:
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">Similarity between your two sentences</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "text 1": "Plants use sunlight to produce energy through photosynthesis.",
#   "text 2": "Photosynthesis converts light energy into chemical energy in plants.",
#   "cosine similarity": 0.6716
# }</pre>
#     </div>

# %% [markdown]
# ## 🎯 Wrap-up
#
# You learned how to *steer* a language model instead of just calling it:
#
# - **Roles**, the system message sets behavior and tone, the user message asks, and a supplied assistant turn primes the model to continue in a chosen style.
# - **Parameters**, `max_tokens` caps how long a reply may be (length and cost), and `temperature` controls how focused or creative it is. You felt both by tuning the `Call_ChatGPT` helper.
# - **Tokens**, the unit the model reads, writes, and bills in, so you can reason about length and cost.
# - **Images**, the same SDK turns a text prompt into a picture, and prompt detail drives the result.
# - **Embeddings**, text becomes a vector, and cosine similarity turns "how alike is the meaning?" into a simple math operation, the foundation of the semantic search and RAG you build later.
#
# With roles and parameters under your control, every later lab becomes about *what* you ask the model to do rather than *how* to make it behave.
